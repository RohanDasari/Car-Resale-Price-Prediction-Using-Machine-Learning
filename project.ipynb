# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('cars.csv')

# %%
dataset.isnull().any()
# Out:
# manufacturer_name    False
# model_name           False
# transmission         False
# color                False
# odometer_value       False
# year_produced        False
# engine_fuel          False
# engine_has_gas       False
# engine_type          False
# engine_capacity       True
# body_type            False
# has_warranty         False
# state                False
# drivetrain           False
# price_usd            False
# is_exchangeable      False
# location_region      False
# number_of_photos     False
# up_counter           False
# feature_0            False
# feature_1            False
# feature_2            False
# feature_3            False
# feature_4            False
# feature_5            False
# feature_6            False
# feature_7            False
# feature_8            False
# feature_9            False
# duration_listed      False
# dtype: bool

# %%
dataset["engine_capacity"].fillna(dataset["engine_capacity"].mean(),inplace=True)

# %%
dataset.isnull().any()
# Out:
# manufacturer_name    False
# model_name           False
# transmission         False
# color                False
# odometer_value       False
# year_produced        False
# engine_fuel          False
# engine_has_gas       False
# engine_type          False
# engine_capacity      False
# body_type            False
# has_warranty         False
# state                False
# drivetrain           False
# price_usd            False
# is_exchangeable      False
# location_region      False
# number_of_photos     False
# up_counter           False
# feature_0            False
# feature_1            False
# feature_2            False
# feature_3            False
# feature_4            False
# feature_5            False
# feature_6            False
# feature_7            False
# feature_8            False
# feature_9            False
# duration_listed      False
# dtype: bool

# %%
x=dataset.iloc[:,1:]

# %%
x
# Out:
#           model_name transmission   color  odometer_value  year_produced  \
# 0            Outback    automatic  silver          190000           2010
# 1            Outback    automatic    blue          290000           2002
# 2           Forester    automatic     red          402000           2001
# 3            Impreza   mechanical    blue           10000           1999
# 4             Legacy    automatic   black          280000           2001
# 5            Outback    automatic  silver          132449           2011
# 6           Forester    automatic   black          318280           1998
# 7             Legacy    automatic  silver          350000           2004
# 8            Outback    automatic    grey          179000           2010
# 9           Forester    automatic  silver          571317           1999
# 10          Forester   mechanical   other          280000           2003
# 11           Tribeca    automatic    grey          256000           2008
# ...

# %%
x.corr()
# Out:
#                   odometer_value  year_produced  engine_has_gas  \
# odometer_value          1.000000      -0.488679        0.057786
# year_produced          -0.488679       1.000000       -0.074686
# engine_has_gas          0.057786      -0.074686        1.000000
# engine_capacity         0.105680       0.005057        0.084579
# has_warranty           -0.189498       0.209231       -0.020667
# price_usd              -0.421204       0.705511       -0.062528
# is_exchangeable         0.042342      -0.057937        0.018646
# number_of_photos       -0.143708       0.258180       -0.032101
# up_counter             -0.020961       0.007945        0.000058
# feature_0               0.105917      -0.346980        0.004089
# feature_1              -0.150960       0.424750       -0.008071
# feature_2              -0.076169       0.205039       -0.012030
# feature_3              -0.229082       0.431307       -0.027034
# feature_4              -0.067292       0.184757        0.003547
# ...

# %%
x.drop(columns="engine_has_gas",inplace=True)
x.drop(columns="up_counter",inplace=True)
x.drop(columns="feature_0",inplace=True)
x.drop(columns="feature_1",inplace=True)
x.drop(columns="feature_2",inplace=True)
x.drop(columns="feature_4",inplace=True)
x.drop(columns="feature_9",inplace=True)
x.drop(columns="is_exchangeable",inplace=True)
x.drop(columns="duration_listed",inplace=True)
x.drop(columns="price_usd",inplace=True)
x.drop(columns="location_region",inplace=True)
x.drop(columns="engine_fuel",inplace=True)
x.drop(columns="drivetrain",inplace=True)
x.drop(columns="number_of_photos",inplace=True)

# %%
x.isnull().any()
# Out:
# model_name         False
# transmission       False
# color              False
# odometer_value     False
# year_produced      False
# engine_type        False
# engine_capacity    False
# body_type          False
# has_warranty       False
# state              False
# feature_3          False
# feature_5          False
# feature_6          False
# feature_7          False
# feature_8          False
# dtype: bool

# %%
x
# Out:
#           model_name transmission   color  odometer_value  year_produced  \
# 0            Outback    automatic  silver          190000           2010
# 1            Outback    automatic    blue          290000           2002
# 2           Forester    automatic     red          402000           2001
# 3            Impreza   mechanical    blue           10000           1999
# 4             Legacy    automatic   black          280000           2001
# 5            Outback    automatic  silver          132449           2011
# 6           Forester    automatic   black          318280           1998
# 7             Legacy    automatic  silver          350000           2004
# 8            Outback    automatic    grey          179000           2010
# 9           Forester    automatic  silver          571317           1999
# 10          Forester   mechanical   other          280000           2003
# 11           Tribeca    automatic    grey          256000           2008
# ...

# %%
y=dataset.iloc[:,14]

# %%
y
# Out:
# 0        10900.00
# 1         5000.00
# 2         2800.00
# 3         9999.00
# 4         2134.11
# 5        14700.00
# 6         3000.00
# 7         4500.00
# 8        12900.00
# 9         4200.00
# 10        6900.00
# 11        8350.00
# 12        4300.00
# 13        1666.00
# 14        8600.00
# 15        7300.00
# 16        7587.97
# 17       10950.00
# 18       12700.00
# 19       16500.00
# 20        8700.00
# 21        7500.00
# 22        8650.00
# 23        3500.00
# 24        3800.00
# 25        7200.00
# 26        1850.00
# 27        3800.00
# 28        3000.00
# 29        6200.00
#            ...
# 38501     4200.00
# 38502     4900.00
# 38503     1300.00
# 38504     3500.00
# 38505     3600.00
# 38506     3793.99
# 38507     6700.00
# 38508     3700.00
# 38509     5500.00
# 38510     7000.00
# 38511     5400.00
# 38512     4100.00
# 38513     3200.00
# 38514     3700.00
# 38515     4200.00
# 38516     3450.00
# 38517     6500.00
# 38518     2800.00
# 38519     2700.00
# ...

# %%
x=x.values
y=y.values

# %%
x
# Out:
# array([['Outback', 'automatic', 'silver', ..., False, True, True],
#        ['Outback', 'automatic', 'blue', ..., False, False, False],
#        ['Forester', 'automatic', 'red', ..., False, False, True],
#        ...,
#        ['300', 'automatic', 'blue', ..., False, False, True],
#        ['PT Cruiser', 'mechanical', 'black', ..., False, False, False],
#        ['Voyager', 'automatic', 'silver', ..., False, False, False]],
#       dtype=object)

# %%
y
# Out:
# array([10900.,  5000.,  2800., ...,  4300.,  4000.,  3200.])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
x[:,0]=lb.fit_transform(x[:,0])

# %%
x
# Out:
# array([[764, 'automatic', 'silver', ..., False, True, True],
#        [764, 'automatic', 'blue', ..., False, False, False],
#        [519, 'automatic', 'red', ..., False, False, True],
#        ...,
#        [86, 'automatic', 'blue', ..., False, False, True],
#        [766, 'mechanical', 'black', ..., False, False, False],
#        [1058, 'automatic', 'silver', ..., False, False, False]],
#       dtype=object)

# %%
lb1=LabelEncoder()

# %%
x[:,1]=lb1.fit_transform(x[:,1])

# %%
x
# Out:
# array([[764, 0, 'silver', ..., False, True, True],
#        [764, 0, 'blue', ..., False, False, False],
#        [519, 0, 'red', ..., False, False, True],
#        ...,
#        [86, 0, 'blue', ..., False, False, True],
#        [766, 1, 'black', ..., False, False, False],
#        [1058, 0, 'silver', ..., False, False, False]], dtype=object)

# %%
lb2=LabelEncoder()
x[:,2]=lb2.fit_transform(x[:,2])

# %%
x
# Out:
# array([[764, 0, 8, ..., False, True, True],
#        [764, 0, 1, ..., False, False, False],
#        [519, 0, 7, ..., False, False, True],
#        ...,
#        [86, 0, 1, ..., False, False, True],
#        [766, 1, 0, ..., False, False, False],
#        [1058, 0, 8, ..., False, False, False]], dtype=object)

# %%
lb3=LabelEncoder()
x[:,5]=lb3.fit_transform(x[:,5])

# %%
x[:,5]
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=object)

# %%
lb4=LabelEncoder()
x[:,7]=lb4.fit_transform(x[:,7])

# %%
x[:,7]
# Out:
# array([10, 10, 9, ..., 8, 6, 6], dtype=object)

# %%
lb5=LabelEncoder()
x[:,8]=lb5.fit_transform(x[:,8])

# %%
lb6=LabelEncoder()
x[:,9]=lb6.fit_transform(x[:,9])

# %%
lb7=LabelEncoder()
x[:,10]=lb7.fit_transform(x[:,10])

# %%
lb8=LabelEncoder()
x[:,11]=lb8.fit_transform(x[:,11])

# %%
lb9=LabelEncoder()
x[:,12]=lb9.fit_transform(x[:,12])

# %%
lb10=LabelEncoder()
x[:,13]=lb10.fit_transform(x[:,13])

# %%
lb11=LabelEncoder()
x[:,14]=lb11.fit_transform(x[:,14])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc=MinMaxScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_test=sc.fit_transform(x_test)

# %%
dataset.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# ...

# %%
plt.plot(x_train,y_train,color='blue')
plt.title('Car_Resale')
plt.xlabel('car_features')
plt.ylabel('price')
plt.show()

# %% [markdown]
# # Using Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg=DecisionTreeRegressor(random_state=0)

# %%
reg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
y_pred=reg.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.32128547153942955

# %% [markdown]
# #  multilinear algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5989285110748095

# %% [markdown]
# # polynomial algorithm

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=3)

# %%
x_poly=pf.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_poly=LinearRegression()

# %%
lr_poly.fit(x_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import r2_score

# %%
y_pred=lr_poly.predict(x_poly)

# %%
y_train.shape
# Out:
# (30824,)

# %%
x_train.shape
# Out:
# (30824, 15)

# %%
r2_score(y,y_pred)
# Out:
# 0.8255645134271008
